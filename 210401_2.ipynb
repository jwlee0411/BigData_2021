# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# fonts-nanum is already the newest version (20170925-1).
# 0 upgraded, 0 newly installed, 0 to remove and 30 not upgraded.
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 10 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /var/cache/fontconfig: cleaning cache directory
# /root/.cache/fontconfig: not cleaning non-existent cache directory
# /root/.fontconfig: not cleaning non-existent cache directory
# fc-cache: succeeded
# ...

# %%
f = open('/content/drive/MyDrive/data/age.csv', 'r', encoding='cp949')


import csv
import matplotlib.pyplot as plt

# %%
f = open('/content/drive/MyDrive/data/age.csv', 'r', encoding='cp949')
data = csv.reader(f)
title = input()
for row in data:
  if title in row[0]:
    result = []
    for i in row[3:104]:
      result.append(int(i.replace(',', '')))
plt.rcParams["font.family"] = 'NanumBarunGothic'
plt.style.use('ggplot')
plt.plot(result)
plt.title(title+"의 인구구조")
plt.show()


import matplotlib.pyplot as plt
import csv
highest_temp_list = []
f = open('/content/drive/MyDrive/data/seoul.csv', 'r', encoding="cp949")
data = csv.reader(f)
next(data)

for element in data:
  if element[-1] != "":
    highest_temp_list.append(float(element[-1]))
plt.hist(highest_temp_list, bins=100)
plt.show()
import numpy as np #numerical python

result2 = [49, 456, 13, 974, 4, 79, 16, 59, 64]
plt.boxplot(highest_temp_list)
plt.show()
# Out:
# 역삼동
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 50669 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49340 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 46041 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 51032 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 51064 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...
